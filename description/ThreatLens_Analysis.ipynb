# %% [markdown]
# ## ThreatLens AI
#
# Data Access Audit & Insider Threat Detection System
#
# Goal:
# Detect abnormal user access patterns using behavioral analytics and machine learning.
#
# Dataset:
# - user_profiles.csv
# - data_access_logs.csv
#
# Model:
# - Isolation Forest
#
# Evaluation:
# - Precision
# - Recall
# - F1 Score

# %%
import pandas as pd

users = pd.read_csv("data/user_profiles.csv")
logs = pd.read_csv("data_access_logs.csv")

print("Users:", users.shape)
print("Logs:", logs.shape)

logs.head()

# %%
logs.info()
